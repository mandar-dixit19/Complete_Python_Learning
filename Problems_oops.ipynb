# %% [markdown]
# <a href="https://colab.research.google.com/github/mandar-dixit19/Complete_Python_Learning/blob/main/Problems_oops.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# problem no 1
class BankAccount:
   # constructor
   def __init__(self, account_no , owner_name, balance):
    self.account_no = account_no
    self.owner_name = owner_name
    self.balance = balance

   # lets defining the methods
   def deposite(self, new_amount):
     self.balance += new_amount
     return self.balance

   def withdraw(self, amount):
    if self.balance > amount:
      self.balance -= amount
      return self.balance
    else:
      print("abbe garib")

   def check_balance(self):
    return self.balance



# lets make a object
Man1 = BankAccount(1234567890, "mandar Dixit", 50_000)
print(Man1.owner_name)
print(Man1.account_no)
print(Man1.balance)
Man1.deposite(5000)
Man1.withdraw(1000)
Man1.withdraw(60000)
Man1.check_balance()
# Out:
# mandar Dixit
# 1234567890
# 50000
# abbe garib
# 54000

# %%
# problem 2
class Book:


  def __init__(self, title, author, reviews):
    self.title = title
    self.author = author
    self.reviews = []


  def count(self):
    return len(self.reviews)


  def add_review(self, review):
    self.reviews.append(review)
    return self.reviews





# make  object
b1 = Book("game of throne", "mandar Dixit", "nice boook")
print(b1.title)

b1.add_review("nice book")
b1.add_review("very clear")
b2 = Book("kjdfj", "mandar", "clear the grammer")
b2.add_review("nice book")
b2.add_review("very clear")
print(b2.count())


print(b1.count())
# Out:
# game of throne
# 2
# 2

# %%
#problem 3
class Student:
  def __init__(self, name ,roll_no, marks):
    #make the all private
    self.__name = name
    self.__roll_no = roll_no
    self.__marks = marks

  # getters
  def get_name(self):
    return self.__name

  def get_roll_no(self):
    return self.__roll_no

  def get_marks(self):
    return self.__marks

  def set_name(self, name):
        if name.strip() == "":
            print("Name cannot be empty")
        else:
            self.name = name

  def set_roll_no(self, roll_no):
        if 1 <= roll_no <= 100:
            self.roll_no = roll_no
        else:
            print("Roll number must be between 1 and 100")

  def set_marks(self, marks):
        if marks >= 0:
            self.marks = marks
        else:
            print("Marks cannot be negative")



s1 = Student("mandar", 5, 90)
s1.get_name()
print(s1.get_name())
print(s1.get_roll_no())
print(s1.get_marks())

print(s1.set_name("name"))
print(s1.set_roll_no(5))
# print(s1.set_roll_no(-5))
# print(s1.set_marks(-300))
# Out:
# mandar
# 5
# 90
# None
# None

# %%
# problem no 4
class Shape:

  def area(self):
    print("area calculation is not happen")

class circle(Shape):
  def __init__(self, radius):
    self.radius = radius

  def area(self):
    return 3.14 * self.radius * self.radius


class Triangle(Shape):
  def __init__(self, base , height):
    self.base = base
    self.height = height

  def area(self):
    return (0.5 * self.base * self.height)


# same for the rectangle


c1 = circle(6)
print(c1.area())

c2 = Triangle(5, 6)
print(c2.area())
# Out:
# 113.03999999999999
# 15.0

# %%
#problem no  5 inheritance
class Vehicle:
  def __init__(self, brand , model):
    self.brand = brand
    self.model = model

class Car(Vehicle):

  def __init__(self, no_seats,brand, model):
    self.no_seats = no_seats
    super().__init__(brand, model)

class Bike(Car):
  def __init__(self,no_seats, brand , model,  engine):
    super().__init__(no_seats, brand, model)
    self.engine = engine



 # let make a object

v1 = Vehicle("tata" , "siarra", )
print(v1.brand, v1.model, )

v2 = Car(5, "tata", "van")
print(v2.no_seats, v2.model, v2.brand)


v3 = Bike(5, "honda", "city", "1500cc")
v3 = Bike(v3.engine, v3.brand, v3.model, v3.no_seats)
print(v3.engine, v3.brand, v3.model, v3.no_seats)
# Out:
# tata siarra
# 5 van tata
# 5 honda city 1500cc

# %%
# problem no 6
from abc import ABC, abstractmethod
class Employee(ABC):
  @abstractmethod
  def calculate_salary():
    pass

class Intern(Employee):
  def calculate_salary(self):
    return print("the sallary is", 50_000)

class Full_time(Employee):
  def calculate_salary(self):
    return print("the sallary is", 100_000)

class contracted(Employee):
  def calculate_salary(self):
    return print("the sallary is", 50_000)



intern = Intern()
intern.calculate_salary()

full_time = Full_time()
full_time.calculate_salary()

contracted = contracted()
contracted.calculate_salary()
# Out:
# the sallary is 50000
# the sallary is 100000
# the sallary is 50000

# %%
#problem no 7
class Person:

    def __init__(self, name, age=None, address=None):
        self.name = name
        self.age = age
        self.address = address

    def display(self):
        print(f"Name: {self.name}")
        print(f"Age: {self.age}")
        print(f"Address: {self.address}")
        print("-" * 20)


# Name only
p1 = Person("Mandar")

# Name + Age
p2 = Person("Mandar", 22)

# Name + Age + Address
p3 = Person("Mandar", 22, "Pune")

p1.display()
p2.display()
p3.display()
# Out:
# Name: Mandar
# Age: None
# Address: None
# --------------------
# Name: Mandar
# Age: 22
# Address: None
# --------------------
# Name: Mandar
# Age: 22
# Address: Pune
# --------------------

# %%
class Player:

    # Class variable
    player_count = 0

    def __init__(self, name, level):
        # Instance variables
        self.name = name
        self.level = level

        # Increment player count whenever a player is created
        Player.player_count += 1


# Create players
p1 = Player("Mandar", 10)
p2 = Player("Rahul", 15)
p3 = Player("Amit", 20)

print("Total Players:", Player.player_count)
# Out:
# Total Players: 3

# %%
#problem no 9
class Herbivore:

    def eat_plants(self):
        print("Eats plants")


class Carnivore:

    def eat_meat(self):
        print("Eats meat")


class Omnivore(Herbivore, Carnivore):

    def eat_both(self):
        print("Eats both plants and meat")


class Bear(Omnivore):

    def __init__(self, name):
        self.name = name

    def display(self):
        print("Bear Name:", self.name)


# Create object
b1 = Bear("Brown Bear")

b1.display()
b1.eat_plants()
b1.eat_meat()
b1.eat_both()
# Out:
# Bear Name: Brown Bear
# Eats plants
# Eats meat
# Eats both plants and meat

# %%
# big problem on oop
class Message:
    message_counter = 1

    def __init__(self, sender, content):
        self.sender = sender
        self.content = content
        self.id = Message.message_counter
        Message.message_counter += 1

    def __str__(self):
        return f"({self.id}) {self.sender.username}: {self.content}"


class User:
    def __init__(self, username):
        self.username = username
        self.chatroom = None

    def join_chatroom(self, chatroom):
        if self.chatroom:
            print(f"{self.username} is already in a chatroom.")
        else:
            chatroom.add_user(self)
            self.chatroom = chatroom
            print(f"{self.username} joined {chatroom.name}")

    def leave_chatroom(self):
        if not self.chatroom:
            print(f"{self.username} is not in any chatroom.")
        else:
            room_name = self.chatroom.name
            self.chatroom.remove_user(self)
            self.chatroom = None
            print(f"{self.username} left {room_name}")

    def send_message(self, content):
        if not self.chatroom:
            print(f"{self.username} is not in any chatroom.")
        else:
            self.chatroom.broadcast(self, content)


class ChatRoom:
    def __init__(self, name):
        self.name = name
        self.users = []
        self.messages = []

    def add_user(self, user):
        self.users.append(user)

    def remove_user(self, user):
        self.users.remove(user)

    def broadcast(self, sender, content):
        message = Message(sender, content)
        self.messages.append(message)
        print(message)

    def show_chat_history(self):
        print(f"\n===== Chat History: {self.name} =====")

        if not self.messages:
            print("No messages yet.")
            return

        for msg in self.messages:
            print(msg)


# --------------------------
# Example Usage
# --------------------------

room = ChatRoom("Python Lounge")

u1 = User("Alice")
u2 = User("Bob")
u3 = User("Charlie")

u1.join_chatroom(room)
u2.join_chatroom(room)

u1.send_message("Hello everyone!")
u2.send_message("Hi Alice!")

u3.join_chatroom(room)
u3.send_message("Hey guys, what's up?")

room.show_chat_history()

u1.leave_chatroom()
u2.leave_chatroom()
u3.leave_chatroom()
# Out:
# Alice joined Python Lounge
# Bob joined Python Lounge
# (1) Alice: Hello everyone!
# (2) Bob: Hi Alice!
# Charlie joined Python Lounge
# (3) Charlie: Hey guys, what's up?
#
# ===== Chat History: Python Lounge =====
# (1) Alice: Hello everyone!
# (2) Bob: Hi Alice!
# (3) Charlie: Hey guys, what's up?
# Alice left Python Lounge
# Bob left Python Lounge
# Charlie left Python Lounge
